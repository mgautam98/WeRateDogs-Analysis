# %% [markdown]
# # Act Report - WeRateDogs

# %% [markdown]
# ## Introduction
#
# [WeRateDogs](https://en.wikipedia.org/wiki/WeRateDogs) is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because ["they're good dogs Brent."](http://knowyourmeme.com/memes/theyre-good-dogs-brent) WeRateDogs has over 4 million followers and has received international media coverage.

# %% [markdown]
# In this project, I have wrangled the data from multiple sources and assessed them for the quality and tideness issues and cleanded the data for achieving great visualizations. I will share many insights into the WeRateDogs today. So, stay tuned.
# Here, is an example of how WeRateDogs rate the good dogs
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Most Common dog name
# How often have to heard a dog named Dragonfly or blackmamba, I guess never. From the Dataset we found out some of the most common dog names. You will not be surprised that one of this is your dog name.
# ![img3.png](./img3.png)
#
# So, some of the most common names for dogs are, Tucker, Oliver, Penny, Cooper, or Charlie

# %% [markdown]
# #### Favourite Count vs Rating given
# WeRateDogs have a very different rating system they tend to rate more than 10 on a scale of 10. Also, some might think whether their rating system is giving good rating to good dogs or not? To answer this I have plotted the favourite counts vs the rating plot. Favourite count is given by the users whereas the rating is given the the WeRateDogs
# ![img2.png](./img2.png)
#
# So, the rating system seems fair, because as the ranting increases, the favourites count also increases means that the people love that dog more.

# %% [markdown]
# #### Common dog Types
# How often have to heard a dog named Dragonfly or blackmamba, I guess never. From the Dataset we found out some of the most common dog names. You will not be surprised that one of this is your dog name.
# ![img4.png](./img4.png)
#
# So, the most common type of dog is pupper. puppy is called pupper in doggo lingo

# %% [markdown]
# #### Average Rating a dog receives
# So, whats an average rating a dog gets? Souupse if you are planning to rate your dog from weRateDogs how much rating is you dog likely to receive?
# It is 1.059. That means on a scale of 10 you dog will likely receive more than 10 rating points

# %% [markdown]
# #### Highest Rated Dog breeds
# Now, we will look at the most awaited result. Which dog breed has got the highest rating form weRateDogs? It is Golden retirver?
# ![img1.png](./img1.png)
#
# Well The golden retirver was getting unfair advantage because of some outliers. After removing it the Bouvier des flandres came as the highest rated dog

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'act_report.ipynb'])
# Out:
# 0
